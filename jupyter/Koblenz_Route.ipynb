# %%
from typing import Tuple, List, Dict

# %%
import pandas as pd

# %%
import folium

# %%
pd.set_option('display.precision', 2)

# %%
df_sites = pd.DataFrame(
    [['Bhf Koblenz Stadtmitte', 50.35834, 7.59015],
     ['Löhrrondel', 50.35722, 7.59175],
     ['Pavillion', 50.35608, 7.59154],
     ['Kreisverwaltungsamt Mayen-Koblenz', 50.35584, 7.59235],
     ['Luftschutzbunker', 50.35419, 7.59489],
     ['Allianzhaus', 50.35541, 7.59456],
     ['Kaiserliche Oberpostdirektion', 50.35489,7.59618],
     ['Theater Koblenz', 50.35821, 7.59888],
     ['Clemensstraße, Wohnbebauung der 1950er', 50.35862, 7.59888],
     ['Ehem. Reichsbankfiliale (heute: Deutsche Bundesbank)', 50.35732492939022, 7.59921648700538],
     ['Gymnasialstraße 4–8', 50.35992, 7.59804],
     ['Jesuitenkirche', 50.36026, 7.59892],
     ['Hochbunker Nagelsgasse', 50.36105, 7.60058]],
    columns=pd.Index(['Objekt', 'latitude', 'longitude'], name='Koblenz')
)

df_sites
# Out:
# Koblenz                                             Objekt  latitude  \
# 0                                   Bhf Koblenz Stadtmitte     50.36
# 1                                               Löhrrondel     50.36
# 2                                                Pavillion     50.36
# 3                        Kreisverwaltungsamt Mayen-Koblenz     50.36
# 4                                         Luftschutzbunker     50.35
# 5                                              Allianzhaus     50.36
# 6                            Kaiserliche Oberpostdirektion     50.35
# 7                                          Theater Koblenz     50.36
# 8                   Clemensstraße, Wohnbebauung der 1950er     50.36
# 9        Ehem. Reichsbankfiliale (heute: Deutsche Bunde...     50.36
# 10                                     Gymnasialstraße 4–8     50.36
# 11                                          Jesuitenkirche     50.36
# 12                                  Hochbunker Nagelsgasse     50.36
#
# Koblenz  longitude
# 0             7.59
# 1             7.59
# 2             7.59
# 3             7.59
# 4             7.59
# 5             7.59
# 6             7.60
# 7             7.60
# 8             7.60
# 9             7.60
# 10            7.60
# 11            7.60
# 12            7.60

# %%
avg_location = df_sites[['latitude', 'longitude']].mean()
Karte_Koblenz = folium.Map(location=avg_location, zoom_start=15)

# %%
for Objekt in df_sites.itertuples():
  marker = folium.Marker(location=(Objekt.latitude, Objekt.longitude),
                         tooltip=Objekt.Objekt)
  marker.add_to(Karte_Koblenz)

Karte_Koblenz
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dd42dc4cfb1f110bc538089f152c8a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dd42dc4cfb1f110bc538089f152c8a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dd42dc4cfb1f110bc538089f152c8a4 = L.map(
#                 &quot;map_9dd42dc4cfb1f110bc538089f152c8a4&quot;,
#                 {
#                     center: [50.357488840722326, 7.595841268231183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0391653c0cdd3dabab8f4fd5f7528647 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             var marker_e5c0c0b0a96855350b7cf92c2e2ca96b = L.marker(
#                 [50.35834, 7.59015],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_e5c0c0b0a96855350b7cf92c2e2ca96b.bindTooltip(
#                 `&lt;div&gt;
#                      Bhf Koblenz Stadtmitte
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fb6529e81af5599a9f16f5ed95d8f4c7 = L.marker(
#                 [50.35722, 7.59175],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_fb6529e81af5599a9f16f5ed95d8f4c7.bindTooltip(
#                 `&lt;div&gt;
#                      Löhrrondel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92980271994fa7d8e47db939ba4a7279 = L.marker(
#                 [50.35608, 7.59154],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_92980271994fa7d8e47db939ba4a7279.bindTooltip(
#                 `&lt;div&gt;
#                      Pavillion
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a112aab6f4ffe050576fb17265918e8f = L.marker(
#                 [50.35584, 7.59235],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_a112aab6f4ffe050576fb17265918e8f.bindTooltip(
#                 `&lt;div&gt;
#                      Kreisverwaltungsamt Mayen-Koblenz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e0f4597f18c693c2ea06bd279537a160 = L.marker(
#                 [50.35419, 7.59489],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_e0f4597f18c693c2ea06bd279537a160.bindTooltip(
#                 `&lt;div&gt;
#                      Luftschutzbunker
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e79461b188c7c5df960d83aac1fdb739 = L.marker(
#                 [50.35541, 7.59456],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_e79461b188c7c5df960d83aac1fdb739.bindTooltip(
#                 `&lt;div&gt;
#                      Allianzhaus
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_082287a1e580bbe690f6fd3009b5bbc5 = L.marker(
#                 [50.35489, 7.59618],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_082287a1e580bbe690f6fd3009b5bbc5.bindTooltip(
#                 `&lt;div&gt;
#                      Kaiserliche Oberpostdirektion
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1fd242ac3ac29719515f70fd555e3ac4 = L.marker(
#                 [50.35821, 7.59888],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_1fd242ac3ac29719515f70fd555e3ac4.bindTooltip(
#                 `&lt;div&gt;
#                      Theater Koblenz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a91cb842a5389b1876711648031c0a31 = L.marker(
#                 [50.35862, 7.59888],
#                 {}
#             ).addTo(map_9dd42dc4cfb1f110bc538089f152c8a4);
#
#
#             marker_a91cb842a5389b1876711648031c0a31.bindTooltip(
#                 `&lt;div&gt;
#                      Clemensstraße, Wohnbebauung der 1950er
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c06f72a1ce6ae311f8a5c22e52a4083b = L.marker(
#                 [50.35732492939022, 7.59921648700538],

# %%
df_route = df_sites.copy()
df_route.index.name = 'Reihenfolge'

df_route
# Out:
# Koblenz                                                 Objekt  latitude  \
# Reihenfolge
# 0                                       Bhf Koblenz Stadtmitte     50.36
# 1                                                   Löhrrondel     50.36
# 2                                                    Pavillion     50.36
# 3                            Kreisverwaltungsamt Mayen-Koblenz     50.36
# 4                                             Luftschutzbunker     50.35
# 5                                                  Allianzhaus     50.36
# 6                                Kaiserliche Oberpostdirektion     50.35
# 7                                              Theater Koblenz     50.36
# 8                       Clemensstraße, Wohnbebauung der 1950er     50.36
# 9            Ehem. Reichsbankfiliale (heute: Deutsche Bunde...     50.36
# 10                                         Gymnasialstraße 4–8     50.36
# 11                                              Jesuitenkirche     50.36
# 12                                      Hochbunker Nagelsgasse     50.36
#
# Koblenz      longitude
# Reihenfolge
# 0                 7.59
# 1                 7.59
# 2                 7.59
# 3                 7.59
# 4                 7.59
# 5                 7.59
# 6                 7.60
# 7                 7.60
# 8                 7.60
# 9                 7.60
# 10                7.60
# 11                7.60
# 12                7.60

# %%
df_route_segments = df_route.join(
    df_route.shift(-1),  # map each stop to its next stop
    rsuffix='_next'
).dropna()  # last stop has no "next one", so drop it

df_route_segments
# Out:
# Koblenz                                                 Objekt  latitude  \
# Reihenfolge
# 0                                       Bhf Koblenz Stadtmitte     50.36
# 1                                                   Löhrrondel     50.36
# 2                                                    Pavillion     50.36
# 3                            Kreisverwaltungsamt Mayen-Koblenz     50.36
# 4                                             Luftschutzbunker     50.35
# 5                                                  Allianzhaus     50.36
# 6                                Kaiserliche Oberpostdirektion     50.35
# 7                                              Theater Koblenz     50.36
# 8                       Clemensstraße, Wohnbebauung der 1950er     50.36
# 9            Ehem. Reichsbankfiliale (heute: Deutsche Bunde...     50.36
# 10                                         Gymnasialstraße 4–8     50.36
# 11                                              Jesuitenkirche     50.36
#
# Koblenz      longitude                                        Objekt_next  \
# Reihenfolge
# 0                 7.59                                         Löhrrondel
# 1                 7.59                                          Pavillion
# 2                 7.59                  Kreisverwaltungsamt Mayen-Koblenz
# 3                 7.59                                   Luftschutzbunker
# 4                 7.59                                        Allianzhaus
# 5                 7.59                      Kaiserliche Oberpostdirektion
# 6                 7.60                                    Theater Koblenz
# 7                 7.60             Clemensstraße, Wohnbebauung der 1950er
# 8                 7.60  Ehem. Reichsbankfiliale (heute: Deutsche Bunde...
# 9                 7.60                                Gymnasialstraße 4–8
# 10                7.60                                     Jesuitenkirche
# 11                7.60                             Hochbunker Nagelsgasse
#
# Koblenz      latitude_next  longitude_next
# Reihenfolge
# 0                    50.36            7.59
# 1                    50.36            7.59
# 2                    50.36            7.59
# 3                    50.35            7.59
# 4                    50.36            7.59
# 5                    50.35            7.60
# 6                    50.36            7.60
# 7                    50.36            7.60
# 8                    50.36            7.60
# 9                    50.36            7.60
# 10                   50.36            7.60
# 11                   50.36            7.60

# %%
Karte_Koblenz = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           tooltip=stop.Objekt)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude),
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.Objekt} to {stop.Objekt_next}",
    )
    # add elements to the map
    marker.add_to(Karte_Koblenz)
    line.add_to(Karte_Koblenz)

# maker for last stop wasn't added in for loop, so adding it now
folium.Marker(location=(stop.latitude_next, stop.longitude_next),
              tooltip=stop.Objekt_next).add_to(Karte_Koblenz);

Karte_Koblenz
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ac43e6a44116c3250fae80a1297743b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ac43e6a44116c3250fae80a1297743b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ac43e6a44116c3250fae80a1297743b = L.map(
#                 &quot;map_0ac43e6a44116c3250fae80a1297743b&quot;,
#                 {
#                     center: [50.357488840722326, 7.595841268231183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44ded23742809b23bf57d2f9300ac2d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             var marker_967c7c3febbfb2b52e49ac05f80007bd = L.marker(
#                 [50.35834, 7.59015],
#                 {}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             marker_967c7c3febbfb2b52e49ac05f80007bd.bindTooltip(
#                 `&lt;div&gt;
#                      Bhf Koblenz Stadtmitte
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_d30a0883c5b930ac4f05eb0f933e9e6d = L.polyline(
#                 [[50.35834, 7.59015], [50.35722, 7.59175]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             poly_line_d30a0883c5b930ac4f05eb0f933e9e6d.bindTooltip(
#                 `&lt;div&gt;
#                      Bhf Koblenz Stadtmitte to Löhrrondel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d44d66a89fd527f0a07a3e0f045f77e = L.marker(
#                 [50.35722, 7.59175],
#                 {}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             marker_9d44d66a89fd527f0a07a3e0f045f77e.bindTooltip(
#                 `&lt;div&gt;
#                      Löhrrondel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_d2f74dfab67f349a651b07d55e124af6 = L.polyline(
#                 [[50.35722, 7.59175], [50.35608, 7.59154]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             poly_line_d2f74dfab67f349a651b07d55e124af6.bindTooltip(
#                 `&lt;div&gt;
#                      Löhrrondel to Pavillion
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d70d5b988a63e4a00b091ed8fe20a49 = L.marker(
#                 [50.35608, 7.59154],
#                 {}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             marker_3d70d5b988a63e4a00b091ed8fe20a49.bindTooltip(
#                 `&lt;div&gt;
#                      Pavillion
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ef5800130bd6c878547fe16596d26854 = L.polyline(
#                 [[50.35608, 7.59154], [50.35584, 7.59235]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0ac43e6a44116c3250fae80a1297743b);
#
#
#             poly_line_ef5800130bd6c878547fe16596d26854.bindTooltip(
#                 `&lt;div&gt;
#                      P

# %%
Karte_Koblenz.save('Route.html')
